# %%
# %matplotlib inline
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from dframeutils.dataframeutils import *
from dframeutils.randutils import *
from dframeutils.summaryutils import *

# %%
mtcars = pd.read_csv("mtcars.csv")

# %%
mtcars[["am", "gear", "carb"]].dtypes
# Out:
# am      int64
# gear    int64
# carb    int64
# dtype: object

# %%
dtype_converter(
    features=["gear", "carb", "am"], df=mtcars,
    data_type=float)[["am", "gear", "carb"]].dtypes
# Out:
# am      float64
# gear    float64
# carb    float64
# dtype: object

# %%
na_count(mtcars.replace([1, 0], np.NAN))
# Out:
#        miss miss_percent
# model     0        0.00%
# mpg       0        0.00%
# cyl       0        0.00%
# disp      0        0.00%
# hp        0        0.00%
# drat      0        0.00%
# wt        0        0.00%
# qsec      0        0.00%
# vs       32      100.00%
# am       32      100.00%
# gear      0        0.00%
# carb      7       21.88%

# %%
na_plot(mtcars.replace([1, 0], np.NAN), font_scale=2, figsize=(15, 6))

# %%
extreme_observations(mtcars, "drat", n_largest=False)
# Out:
#                  model   mpg  cyl   disp   hp  drat    wt   qsec  vs   am  \
# 5              Valiant  18.1    6  225.0  105  2.76  3.46  20.22   1  0.0
# 21    Dodge Challenger  15.5    8  318.0  150  2.76  3.52  16.87   0  0.0
# 14  Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.25  17.98   0  0.0
#
#     gear  carb
# 5    3.0   1.0
# 21   3.0   2.0
# 14   3.0   4.0

# %%
df_numerical_summary(mtcars)
# Out:
#       count    mean    mode  median     std    min     max  nunique  nzeros  \
# mpg    32.0   20.09   10.40   19.20    6.03  10.40   33.90       25       0
# cyl    32.0    6.19    8.00    6.00    1.79   4.00    8.00        3       0
# disp   32.0  230.72  275.80  196.30  123.94  71.10  472.00       27       0
# hp     32.0  146.69  110.00  123.00   68.56  52.00  335.00       22       0
# drat   32.0    3.60    3.07    3.70    0.53   2.76    4.93       22       0
# wt     32.0    3.22    3.44    3.32    0.98   1.51    5.42       29       0
# qsec   32.0   17.85   17.02   17.71    1.79  14.50   22.90       30       0
# vs     32.0    0.44    0.00    0.00    0.50   0.00    1.00        2      18
# am     32.0    0.41    0.00    0.00    0.50   0.00    1.00        2      19
# gear   32.0    3.69    3.00    4.00    0.74   3.00    5.00        3       0
# carb   32.0    2.81    2.00    2.00    1.62   1.00    8.00        6       0
#
# ...

# %%
correlation_matrix_plot(mtcars)
